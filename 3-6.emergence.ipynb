# %%
from techminer2.tech_mining.emergence import emergent_topics

topics = emergent_topics(
    #
    # FUNCTION PARAMS:
    field='descriptors',
    #
    # EMERGENCE:
    baseline_periods=2,
    recent_periods=2,
    novelty_threshold=0.15,
    total_records_threshold=7,
    periods_with_at_least_one_record=2,
    ratio_threshold=2.0,
    #
    # DATABASE PARAMS:
    root_dir="./", 
    database="main",
    year_filter=(2014, 2023),
    cited_by_filter=(None, None),
)
topics.sort_values(by="OCC", ascending=False)
# Out:
#                           OCC  OCC_baseline  OCC_recent  nonzero_years  \
# descriptors
# PRESENT_VALUES             23             1           7              7
# ELECTRICITY_PRICES         21             1           7              9
# UNCERTAINTY                19             0           5              8
# DECISION_MAKING            19             0           8              8
# ENERGY_POLICY              19             0           6              7
# POWER_GENERATION           18             1           6              8
# MANAGERIAL_FLEXIBILITY     17             1           5              9
# DEFER_OPTION               16             1           5              6
# CARBON_EMISSIONS           14             1           3              8
# SENSITIVITY_ANALYSIS       14             0           4              8
# NET_PRESENT_VALUE          13             1           4              7
# ELECTRICITY_GENERATION     13             1           4              7
# ...

# %%
from techminer2.science_mapping.co_occurrence import communities

comm = communities(
    #
    # PARAMS:
    field="descriptors",
    #
    # COLUMN PARAMS:
    top_n=None,
    occ_range=(None, None),
    gc_range=(None, None),
    custom_items=topics.index.to_list(),
    #
    # NETWORK PARAMS:
    algorithm_or_dict="louvain",
    association_index="association",
    #
    # DATABASE PARAMS:
    root_dir="./",
    database="main",
    year_filter=(2014, 2023),
    cited_by_filter=(None, None),
)
comm.head(50)
# Out:
# Note: to be able to use all crisp methods, you need to install some additional packages:  {'wurlitzer', 'graph_tool', 'bayanpy', 'infomap'}
# Note: to be able to use all crisp methods, you need to install some additional packages:  {'pyclustering', 'ASLPAw'}
# Note: to be able to use all crisp methods, you need to install some additional packages:  {'wurlitzer', 'infomap'}
#                                 CL_0                            CL_1  \
# 0         ELECTRICITY_PRICES 21:0305          PRESENT_VALUES 23:0171
# 1            DECISION_MAKING 19:0190  MANAGERIAL_FLEXIBILITY 17:0153
# 2               DEFER_OPTION 16:0206       NET_PRESENT_VALUE 13:0160
# 3       SENSITIVITY_ANALYSIS 14:0272      CASH_FLOW_ANALYSIS 11:0070
# 4      INVESTMENT_EVALUATION 12:0261  BINOMIAL_DECISION_TREE 09:0025
# 5   LEAST_SQUARE_MONTE_CARLO 12:0246          PROJECT_VALUES 08:0128
# 6            FEED_IN_TARIFFS 12:0228         RISK_PERCEPTION 07:0071
# ...

# %%
from techminer2.science_mapping.co_occurrence import report


report(
    field='descriptors',
    #
    # COLUMN PARAMS:
    top_n=None,
    occ_range=(None, None),
    gc_range=(None, None),
    custom_items=topics.index.to_list(),
    #
    # NETWORK PARAMS:
    algorithm_or_dict="louvain",
    association_index="association",
    #
    # DATABASE PARAMS:
    root_dir="./",
    database="main",
    year_filter=(2014, 2023),
    cited_by_filter=(None, None),
)
# Out:
# --INFO-- The file './reports/co_occurrence/CL_0_relationships_prompt.txt' was created.
# --INFO-- The file './reports/co_occurrence/CL_1_relationships_prompt.txt' was created.
# --INFO-- The file './reports/co_occurrence/CL_2_relationships_prompt.txt' was created.
# --INFO-- The file './reports/co_occurrence/CL_3_relationships_prompt.txt' was created.
