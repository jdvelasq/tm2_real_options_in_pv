# %%
from techminer2.tools import coverage

coverage(
    field="descriptors",
    #
    # DATABASE PARAMS:
    root_dir="./",
    database="main",
    year_filter=(None, None),
    cited_by_filter=(None, None),
).tail(10)
# Out:
# --INFO-- Number of documents : 163
# --INFO--   Documents with NA : 0
# --INFO--  Efective documents : 163
#     min_occ  cum_sum_documents  coverage  cum num items
# 16       10                152   93.25 %             38
# 17        9                154   94.48 %             43
# 18        8                154   94.48 %             48
# 19        7                156   95.71 %             58
# 20        6                157   96.32 %             72
# 21        5                160   98.16 %            100
# 22        4                161   98.77 %            133
# 23        3                162   99.39 %            232
# 24        2                163  100.00 %            581
# 25        1                163  100.00 %           3555

# %% [markdown]
# ---

# %%
from techminer2.refine.thesaurus.descriptors import apply_thesaurus, list_cleanup
from techminer2.science_mapping.co_occurrence import communities

list_cleanup(root_dir="./")
apply_thesaurus(root_dir="./")

comm = communities(
    #
    # PARAMS:
    field="descriptors",
    #
    # COLUMN PARAMS:
    top_n=None,
    occ_range=(5, None),
    gc_range=(None, None),
    custom_items=None,
    #
    # NETWORK PARAMS:
    algorithm_or_dict="louvain",
    association_index="association",
    #
    # DATABASE PARAMS:
    root_dir="./",
    database="main",
    year_filter=(None, None),
    cited_by_filter=(None, None),
)
comm.head(10)
# Out:
# Note: to be able to use all crisp methods, you need to install some additional packages:  {'bayanpy', 'infomap', 'graph_tool', 'wurlitzer'}
# Note: to be able to use all crisp methods, you need to install some additional packages:  {'pyclustering', 'ASLPAw'}
# Note: to be able to use all crisp methods, you need to install some additional packages:  {'infomap', 'wurlitzer'}
# --INFO-- Applying `descriptors.the.txt` thesaurus to author/index keywords and abstract/title words
#                               CL_0                             CL_1  \
# 0    INVESTMENT_DECISIONS 107:1549                   COSTS 038:0942
# 1          PRESENT_VALUES 030:0239        POWER_GENERATION 022:0477
# 2               ECONOMICS 026:0433           ENERGY_POLICY 021:0513
# 3         DECISION_MAKING 025:0213      ELECTRICITY_PRICES 020:0360
# 4      STOCHASTIC_PROCESS 023:0343  ELECTRICITY_GENERATION 016:0144
# 5       NET_PRESENT_VALUE 023:0229         FEED_IN_TARIFFS 014:0382
# 6  MANAGERIAL_FLEXIBILITY 019:0157             WIND_ENERGY 011:0249
# 7            DEFER_OPTION 018:0247            OPTIMIZATION 010:0153
# 8      CASH_FLOW_ANALYSIS 014:0112       ECONOMIC_ANALYSIS 009:0118
# 9         RISK_ASSESSMENT 012:0039            POWER_PLANTS 008:0160
#
#                                  CL_2  \
# 0       UNCERTAINTY_ANALYSIS 033:0778
# 1        MONTE_CARLO_METHODS 026:0378
# 2           CARBON_EMISSIONS 022:0592
# 3                UNCERTAINTY 021:0582
# 4           INVESTMENT_COSTS 016:0565
# 5       SENSITIVITY_ANALYSIS 014:0272
# 6                     CARBON 012:0545
# 7   LEAST_SQUARE_MONTE_CARLO 012:0246
# 8  OPTIMAL_INVESTMENT_TIMING 012:0239
# 9              CARBON_PRICES 010:0497
#
#                                             CL_3
# 0                        ENERGY_MARKETS 020:0426
# 1                 INVESTMENT_EVALUATION 016:0298
# 2  ELECTRIC_POWER_TRANSMISSION_NETWORKS 011:0097
# 3                     INVESTMENT_TIMING 010:0111
# 4                           SMART_GRIDS 010:0070
# 5                        ENERGY_STORAGE 009:0051
# 6                               HOUSING 008:0106
# 7                      NUMERICAL_MODELS 007:0188
# 8               ELECTRIC_ENERGY_STORAGE 007:0044
# 9                         POWER_SYSTEMS 006:0082

# %% [markdown]
# ---

# %%
from techminer2.science_mapping.co_occurrence import communities_summary

m = communities_summary(
    field="descriptors",
    conserve_counters=False,
    top_n=None,
    occ_range=(5, None),
    algorithm_or_dict="louvain",
    association_index="association",
    root_dir="./",
    year_filter=(None, None),
)

m["Terms"] = m["Terms"].str.split("; ")
m["Terms"] = m["Terms"].map(lambda x: [t.strip() for t in x[:10]])
m["Terms"] = m["Terms"].str.join("; ")

print(m.to_markdown())
# Out:
# |    | Cluster   |   Num Terms |   Percentage | Terms                                                                                                                                                                                          |
# |---:|:----------|------------:|-------------:|:-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# |  0 | CL_0      |          33 |           33 | INVESTMENT_DECISIONS; PRESENT_VALUES; ECONOMICS; DECISION_MAKING; STOCHASTIC_PROCESS; NET_PRESENT_VALUE; MANAGERIAL_FLEXIBILITY; DEFER_OPTION; CASH_FLOW_ANALYSIS; RISK_ASSESSMENT             |
# |  1 | CL_1      |          27 |           27 | COSTS; POWER_GENERATION; ENERGY_POLICY; ELECTRICITY_PRICES; ELECTRICITY_GENERATION; FEED_IN_TARIFFS; WIND_ENERGY; OPTIMIZATION; ECONOMIC_ANALYSIS; POWER_PLANTS                                |
# |  2 | CL_2      |          20 |           20 | UNCERTAINTY_ANALYSIS; MONTE_CARLO_METHODS; CARBON_EMISSIONS; UNCERTAINTY; INVESTMENT_COSTS; SENSITIVITY_ANALYSIS; CARBON; LEAST_SQUARE_MONTE_CARLO; OPTIMAL_INVESTMENT_TIMING; CARBON_PRICES   |
# |  3 | CL_3      |          20 |           20 | ENERGY_MARKETS; INVESTMENT_EVALUATION; ELECTRIC_POWER_TRANSMISSION_NETWORKS; INVESTMENT_TIMING; SMART_GRIDS; ENERGY_STORAGE; HOUSING; NUMERICAL_MODELS; ELECTRIC_ENERGY_STORAGE; POWER_SYSTEMS |

# %%
m.to_csv("tables/clusters_summary.csv", sep="\t")

# %% [markdown]
# ---

# %%
from techminer2.analyze.co_occurrence.network import to_brute_force_labels
from techminer2.analyze.pca.cooc_matrix.brute_force import factor_map

# %%
#
# Generate a dictionary with the filtered terms (by time period and
# occurrence) and the assigned cluster
brute_force_labels = to_brute_force_labels(
    #
    # PARAMS:
    field="author_keywords",
    #
    # COLUMN PARAMS:
    top_n=None,
    occ_range=(3, None),
    gc_range=(None, None),
    custom_items=None,
    #
    # NETWORK PARAMS:
    algorithm_or_dict="louvain",
    association_index="association",
    #
    # DATABASE PARAMS:
    root_dir="./",
    database="main",
    year_filter=(2008, 2024),
    cited_by_filter=(None, None),
)

#
# Generate a list of custom items conformed by the author keywords
# used to obtain the clusters
custom_items = [" ".join(term.split(" ")[:-1]) for term in brute_force_labels.keys()]

# %%
factor_map(
    #
    # PARAMS:
    field="author_keywords",
    association_index=None,
    #
    # ITEM PARAMS:
    top_n=None,
    occ_range=(3, None),
    gc_range=(None, None),
    custom_items=custom_items,
    #
    # PCA PARAMS:
    n_components=5,
    whiten=False,
    svd_solver="auto",
    pca_tol=0.0,
    iterated_power="auto",
    n_oversamples=10,
    power_iteration_normalizer="auto",
    random_state=0,
    #
    # BRUTE FORCE PARAMS:
    brute_force_labels=brute_force_labels,
    #
    # LAYOUT:
    nx_k=None,
    nx_iterations=5,
    nx_random_state=4,
    #
    # NODES:
    node_color="#7793a5",
    node_size_range=(16, 40),
    textfont_size_range=(8, 13),
    textfont_opacity_range=(0.35, 1.00),
    #
    # EDGES:
    edge_top_n=None,
    edge_similarity_min=None,
    edge_widths=(2, 2, 3, 3),
    edge_colors=("#7793a5", "#7793a5", "#7793a5", "#7793a5"),
    #
    # AXES:
    xaxes_range=None,
    yaxes_range=None,
    show_axes=False,
    #
    # DATABASE PARAMS:
    root_dir="./",
    database="main",
    year_filter=(2018, None),
    cited_by_filter=(None, None),
).update_layout(width=900, height=700)

# %% [markdown]
# ---

# %%
from techminer2.analyze.words import trending_words_per_year

# %%
trending_words_per_year(
    #
    # PARAMS:
    field="author_keywords",
    n_words_per_year=8,
    custom_items=custom_items,
    #
    # DATABASE PARAMS:
    root_dir="./",
    database="main",
    year_filter=(2018, None),
    cited_by_filter=None,
).fig_.update_layout(width=900, height=1100, yaxis=dict(tickfont=dict(size=10)))

# %% [markdown]
# ---

# %%
from techminer2.analyze.co_occurrence.network import communities_summary
from techminer2.refine.thesaurus.words import apply_thesaurus


def generate_json_data():
    data = {}

    for year in range(2021, 2024):
        print(year, end="  ")

        if year == 2021:
            year_filter = (2018, 2021)
        else:
            year_filter = (year, year)

        m = communities_summary(
            #
            # PARAMS:
            field="author_keywords",
            #
            # SUMMARY PARAMS:
            conserve_counters=False,
            #
            # FILTER PARAMS:
            top_n=None,
            occ_range=(3, None),
            gc_range=(None, None),
            # custom_items=custom_items,
            custom_items=None,
            #
            # NETWORK PARAMS:
            algorithm_or_dict="louvain",
            association_index="association",
            #
            # DATABASE PARAMS:
            root_dir="./",
            database="main",
            year_filter=year_filter,
            cited_by_filter=(None, None),
        )

        m["Terms"] = m["Terms"].str.split("; ")
        m["Terms"] = m["Terms"].map(lambda x: [t.strip() for t in x[:10]])

        data[str(year)] = {}
        for cluster in range(m.shape[0]):
            data[str(year)][str(cluster)] = m["Terms"][cluster]

    return data


#
# Generate the data for the clusters per year.
apply_thesaurus(root_dir="./")
json_data = generate_json_data()

for key in json_data.keys():
    print(f"{key} {len(json_data[key])}")

# %%
import sankey

# 2021 7
# 2022 8
# 2023 6


def flip_cluster(json_data, year, c1, c2):
    aux = json_data[year][c1]
    json_data[year][c1] = json_data[year][c2]
    json_data[year][c2] = aux
    return json_data


# json_data = flip_cluster(json_data, '2023', '0', '1')
# json_data = flip_cluster(json_data, '2022', '0', '3')
# json_data = flip_cluster(json_data, '2021', '0', '4')
# json_data = flip_cluster(json_data, '2020', '0', '5')
# json_data = flip_cluster(json_data, '2017', '0', '1')
# json_data = flip_cluster(json_data, '2016', '0', '1')
# json_data = flip_cluster(json_data, '2023', '1', '4')
# json_data = flip_cluster(json_data, '2022', '1', '3')
# json_data = flip_cluster(json_data, '2021', '1', '2')
# json_data = flip_cluster(json_data, '2020', '1', '2')
# json_data = flip_cluster(json_data, '2019', '1', '4')
# json_data = flip_cluster(json_data, '2023', '2', '3')
# json_data = flip_cluster(json_data, '2022', '2', '3')
# json_data = flip_cluster(json_data, '2022', '3', '4')
# json_data = flip_cluster(json_data, '2020', '2', '5')
# json_data = flip_cluster(json_data, '2019', '2', '4')
# json_data = flip_cluster(json_data, '2019', '3', '4')
# json_data = flip_cluster(json_data, '2018', '3', '4')
# json_data = flip_cluster(json_data, '2017', '1', '2')
# json_data = flip_cluster(json_data, '2017', '2', '3')

sankey.make_sankey_plot(
    json_data,
    y=[
        #
        # 2021: 7
        0.05,
        0.22,
        0.40,
        0.55,
        0.70,
        0.89,
        0.99,
        #
        # 2022: 8
        0.11,
        0.27,
        0.44,
        0.592,
        0.75,
        0.80,
        0.925,
        1.06,
        #
        # 2023: 6
        0.045,
        0.18,
        0.34,
        0.53,
        0.70,
        0.86,
    ],
    color=None,
).update_layout(width=1600, height=1000).show()

# %%
json_data

# %%
display(1)

# %%
display()
